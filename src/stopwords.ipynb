# %%
from nltk.corpus import stopwords
from stop_words import get_stop_words
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
en_stop = get_stop_words('en')
stop_words = stopwords.words("english")
        
stop_words.extend(en_stop)

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
stop_words.extend(['like', 'got', 'get', 'one', 'well', 'bit', 'drive', 'look', 'see', 'good',
                   'quite', 'think', 'little', 'right', 'know', 'thing', 'want','put', 'yeah', 'lot',
                   'dot', 'le', "'ve", 'really', 'like', 'got', 'get', 'one', 'well', 'let', 'gon', 'dhe'
                   'back', 'dhe', 'gon', 'let', 'get', "\'re", "n\'t", "'ve", "really", "car", "cars",
                           'fine', 'needed', 'stretched', 'sexy', 'bought', 'say', 'kind', 'mean',
                          'say', 'come', 'kind', 'fact', 'something', 'going', 'looking', 'guy', 'first', 'second'
                          'term', 'note', 'leader', 'economy', 'choice', 'range', 'twin', 'value', 'led', 'done',
                          'set', 'tell', 'yeah', 'find', 'fun', 'go', 'time', 'course', 'driver', 'review', 'change',
                           'line', 'test', 'turn', 'number', 'way', 'people', 'room', 'stuff', 'place', 'side',
                          'piont', 'show', 'part', 'side', 'move', 'mode', 'case', 'difference', 'front', 'feel',
                          'work', 'need', 'hill', 'road', 'love', 'day', 'term', 'toe', 'today', 'check', 'centre', 
                          'job', 'kid', 'fat', 'ton', 'thank', 'thanks','elektronik', 'instance', 'presence', 'body',
                           'man', 'card'])

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def get_stopwords():
    return stop_words
